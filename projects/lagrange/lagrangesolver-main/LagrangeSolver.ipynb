# %%
import sympy as smp
import numpy as np
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib.animation import FuncAnimation

smp.init_printing()

# Enable interactive plot
# %matplotlib notebook

plt.style.use('dark_background')

# %%
# PÉNDULOS UNIDOS POR RESORTES
# input_r = ['l*cos(phi1) * xhat + l*sin(phi1) * yhat', 'l*cos(phi2) * xhat + l*sin(phi2) * yhat']
# input_V = '-g*l*(m1*cos(phi1) + m2*cos(phi2)) + 1/2*5*(l*((cos(phi2)-cos(phi1))**2 + (sin(phi2) - sin(phi1))**2))'
# parameters = ['l', 'g']

# initial_conditions = [np.pi, -np.pi/4, 0, 0]
# m_values = [1, 2]
# p_values = [1, 10]

# %%
#PÉNDULO DOBLE
input_r = ['l*cos(phi1) * xhat + l*sin(phi1) * yhat', 'l*(cos(phi1) + cos(phi2)) * xhat + l*(sin(phi1) + sin(phi2)) * yhat']
input_V = '-2*m1*g*l*cos(phi1) - m2*g*l*cos(phi2)'
parameters = ['l', 'g']

initial_conditions = [np.pi, -np.pi/4, 0, 0]
m_values = [1, 2]
p_values = [1, 10]

# %%
# PÉNDULO TRIPLE
input_r = ['l1*cos(phi1) * xhat + l1*sin(phi1) * yhat', '(l1*cos(phi1) + l2*cos(phi2)) * xhat + (l1*sin(phi1) + l2*sin(phi2)) * yhat', '(l1*cos(phi1) + l2*cos(phi2) + l3*cos(phi3)) * xhat + (l1*sin(phi1) + l2*sin(phi2) + l3*sin(phi3)) * yhat']
#input_V = '-3*m1*g*l*cos(phi1) - 2*m2*g*l*cos(phi2) - m3*g*l*cos(phi3)'
input_V = '-m1*g*l1*cos(phi1) - m2*g*(l1*cos(phi1) + l2*cos(phi2)) - m3*g*(l1*cos(phi1) + l2*cos(phi2) + l3*cos(phi3))'
parameters = ['l1', 'l2', 'l3', 'g']

initial_conditions = [np.pi, -np.pi/4, np.pi/4, 0, 0, 0]
m_values = [1, 2, 1.5]
p_values = [1, 1, 1, 10]

# %%
# # PÉNDULO CUÁDRUPLE
# input_r = ['L*cos(phi1) * xhat + L*sin(phi1) * yhat', '(L*cos(phi1) + L*cos(phi2)) * xhat + (L*sin(phi1) + L*sin(phi2)) * yhat', '(L*cos(phi1) + L*cos(phi2) + L*cos(phi3)) * xhat + (L*sin(phi1) + L*sin(phi2) + L*sin(phi3)) * yhat', '(L*cos(phi1) + L*cos(phi2) + L*cos(phi3) + L*cos(phi4)) * xhat + (L*sin(phi1) + L*sin(phi2) + L*sin(phi3) + L*sin(phi4)) * yhat']
# input_V = '-m*g*L*cos(phi1) - m*g*(L*cos(phi1) + L*cos(phi2)) - m*g*(L*cos(phi1) + L*cos(phi2) + L*cos(phi3)) - m*g*(L*cos(phi1) + L*cos(phi2) + L*cos(phi3) + L*cos(phi4))'
# parameters = ['L', 'g']

# initial_conditions = [np.pi, -np.pi/4, np.pi/4, 0, 0, 0, 0, 0]
# m_values = [1]
# p_values = [1, 10]

# %%
# PÉNDULO CON RESORTES
# input_r = ['r*cos(phi) * xhat + r*sin(phi) * yhat']
# input_V = '-m1*g*r*cos(phi) + 1/2 * k * (r-l0) ** 2'
# parameters = ['g', 'k', 'l0']

# initial_conditions = [1, np.pi/2, 0, 0]
# m_values = [1]
# p_values = [10, 10, 0.5]

# %%
# input_r = ['l*cos(phi1) * xhat + l*sin(phi1) * yhat', 'r*cos(phi2) * xhat + r*sin(phi2) * yhat']
# input_V = '-m1*g*l*cos(phi1) - G*m1*m2 / sqrt((l*cos(phi1) - r*cos(phi2) + 0.3)**2 + (l*sin(phi1) - r*sin(phi2) + 0.3)**2)'
# parameters = ['g', 'l', 'G']

# initial_conditions = [1, np.pi/2, 1, 0, 0, 0]
# m_values = [1, 1]
# p_values = [10, 1, 0.1]

# %%
# PÉNDULO CON GRAVEDAD NEWTONIANA
# input_r = ['(x + l*cos(phi)) * xhat + l*sin(phi) * yhat']
# input_V = '-G*m1/(L - l*cos(phi))'
# parameters = ['G', 'l', 'L']

# initial_conditions = [np.pi/2, 0, 0, 0]
# m_values = [1]
# p_values = [1, 1, 1.1]

# %%
# DOS CUERPOS
# input_r = ['r1*cos(phi1) * xhat + r1*sin(phi1) * yhat', 'r2*cos(phi2) * xhat + r2*sin(phi2) * yhat']
# input_V = '- G*m1*m2 / sqrt((r1*cos(phi1) - r1*cos(phi2) + e)**2 + (r1*sin(phi1) - r2*sin(phi2) + e)**2)'
# parameters = ['G', 'e']

# initial_conditions = [1, np.pi/2, 1, 0, 0, 0, 0, 0]
# m_values = [1, 1]
# p_values = [1, 0.1]

# %%
# SWINGING PENDULO DOBLE
# input_r = ['x * xhat + 0 * yhat', '(x + l1*cos(phi1)) * xhat + l1*sin(phi1) * yhat', '(x + l1*cos(phi1) + l2*cos(phi2)) * xhat + (l1*sin(phi1) + l2*sin(phi2)) * yhat']
# input_V = '-2*m1*g*l1*cos(phi1) - m2*g*l2*cos(phi2)'
# parameters = ['l1', 'l2', 'g']

# initial_conditions = [0, np.pi, -np.pi/4, 0, 0, 0]
# m_values = [1, 2, 1]
# p_values = [1, 10, 1]

# %%
# PÉNDULO SIMPLE
# input_r = ['(l*cos(phi)) * xhat + l*sin(phi) * yhat']
# input_V = '-m1*g*l*cos(phi)'
# parameters = ['l', 'g']

# initial_conditions = [np.pi, 0]
# m_values = [1]
# p_values = [1, 10]

# %%
fps = 50
t_final = 60
frames_number = fps*t_final
t_values = np.linspace(0, t_final, frames_number)

# %%
t = smp.symbols('t', real=True, positive=True)
r = []

q = []
q_to_coordinates = {}
n = 0
for input_ri in input_r:
    # Get the symbols
    eq = smp.S(input_ri, evaluate=False)
    symbols = eq.free_symbols

    for symbol in symbols:
        if str(symbol) not in parameters and str(symbol) not in q_to_coordinates and str(symbol) not in ('xhat', 'yhat'):
            q.append(smp.Function(str(symbol))(t))
            q_to_coordinates[str(symbol)] = q[n]
            n+=1
        
    
    r_i = smp.parse_expr(input_ri, q_to_coordinates)

    # Cartesian coordinates
    if smp.diff(r_i, 'rhat') == 0 and smp.diff(r_i, 'phihat') == 0:
        rx = smp.diff(r_i, 'xhat')
        ry = smp.diff(r_i, 'yhat')
        r.append([smp.Matrix([rx, ry])][0])

V = smp.parse_expr(input_V, q_to_coordinates)
        

r, V
# Out:
# ⎛⎡⎡l₁⋅cos(φ₁(t))⎤  ⎡l₁⋅cos(φ₁(t)) + l₂⋅cos(φ₂(t))⎤  ⎡l₁⋅cos(φ₁(t)) + l₂⋅cos(φ₂
# ⎜⎢⎢             ⎥, ⎢                             ⎥, ⎢
# ⎝⎣⎣l₁⋅sin(φ₁(t))⎦  ⎣l₁⋅sin(φ₁(t)) + l₂⋅sin(φ₂(t))⎦  ⎣l₁⋅sin(φ₁(t)) + l₂⋅sin(φ₂
#
# (t)) + l₃⋅cos(φ₃(t))⎤⎤
#                     ⎥⎥, -g⋅l₁⋅m₁⋅cos(φ₁(t)) - g⋅m₂⋅(l₁⋅cos(φ₁(t)) + l₂⋅cos(φ₂(
# (t)) + l₃⋅sin(φ₃(t))⎦⎦
#
#                                                            ⎞
# t))) - g⋅m₃⋅(l₁⋅cos(φ₁(t)) + l₂⋅cos(φ₂(t)) + l₃⋅cos(φ₃(t)))⎟
#                                                            ⎠

# %%
N = len(r) # número de partículas
m = smp.symbols(['m%d' % (i + 1) for i in range(N)], real=True, positive=True)
p = smp.symbols(tuple(parameters), real=True)

q_d = []
q_dd = []
for u in range(n):
    q_d.append(smp.diff(q[u],t))
    q_dd.append(smp.diff(q_d[u],t))

# %%
# Calculo la energía cinética 

T = 0
for u in range(n):
    for v in range(n):
        for i in range(N):
            T += m[i]*r[i].diff(q[u]).dot(r[i].diff(q[v])) * q_d[u] * q_d[v]
            
T = smp.Rational(1,2)*T

L = T-V

print('El lagrangiano:')
L.simplify()
# Out:
# El lagrangiano:
#
#
#
#
# g⋅l₁⋅m₁⋅cos(φ₁(t)) + g⋅m₂⋅(l₁⋅cos(φ₁(t)) + l₂⋅cos(φ₂(t))) + g⋅m₃⋅(l₁⋅cos(φ₁(t)
#
#
#                                                        2                     2
#                                        2    ⎛d        ⎞      2    ⎛d        ⎞
#                                      l₁ ⋅m₁⋅⎜──(φ₁(t))⎟    l₁ ⋅m₂⋅⎜──(φ₁(t))⎟
#                                             ⎝dt       ⎠           ⎝dt       ⎠
# ) + l₂⋅cos(φ₂(t)) + l₃⋅cos(φ₃(t))) + ─────────────────── + ───────────────────
#                                               2                     2
#
#                      2
#      2    ⎛d        ⎞
#    l₁ ⋅m₃⋅⎜──(φ₁(t))⎟
#           ⎝dt       ⎠                                d         d
#  + ─────────────────── + l₁⋅l₂⋅m₂⋅cos(φ₁(t) - φ₂(t))⋅──(φ₁(t))⋅──(φ₂(t)) + l₁⋅
#             2                                        dt        dt
#
#
#
#
#                          d         d                                       d
# l₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅──(φ₁(t))⋅──(φ₂(t)) + l₁⋅l₃⋅m₃⋅cos(φ₁(t) - φ₃(t))⋅──(
#                          dt        dt                                      dt
#
#                                      2                     2
#                      2    ⎛d        ⎞      2    ⎛d        ⎞
#                    l₂ ⋅m₂⋅⎜──(φ₂(t))⎟    l₂ ⋅m₃⋅⎜──(φ₂(t))⎟
#        d                  ⎝dt       ⎠           ⎝dt       ⎠
# φ₁(t))⋅──(φ₃(t)) + ─────────────────── + ─────────────────── + l₂⋅l₃⋅m₃⋅cos(φ₂
#        dt                   2                     2
#
#                                                      2
#                                      2    ⎛d        ⎞
#                                    l₃ ⋅m₃⋅⎜──(φ₃(t))⎟
#              d         d                  ⎝dt       ⎠
# (t) - φ₃(t))⋅──(φ₂(t))⋅──(φ₃(t)) + ───────────────────
#              dt        dt                   2

# %%
print(L)
# Out:
# g*l1*m1*cos(phi1(t)) + g*m2*(l1*cos(phi1(t)) + l2*cos(phi2(t))) + g*m3*(l1*cos(phi1(t)) + l2*cos(phi2(t)) + l3*cos(phi3(t))) + m1*(l1**2*sin(phi1(t))**2 + l1**2*cos(phi1(t))**2)*Derivative(phi1(t), t)**2/2 + m2*(l1**2*sin(phi1(t))**2 + l1**2*cos(phi1(t))**2)*Derivative(phi1(t), t)**2/2 + m2*(l2**2*sin(phi2(t))**2 + l2**2*cos(phi2(t))**2)*Derivative(phi2(t), t)**2/2 + m2*(l1*l2*sin(phi1(t))*sin(phi2(t)) + l1*l2*cos(phi1(t))*cos(phi2(t)))*Derivative(phi1(t), t)*Derivative(phi2(t), t) + m3*(l1**2*sin(phi1(t))**2 + l1**2*cos(phi1(t))**2)*Derivative(phi1(t), t)**2/2 + m3*(l2**2*sin(phi2(t))**2 + l2**2*cos(phi2(t))**2)*Derivative(phi2(t), t)**2/2 + m3*(l3**2*sin(phi3(t))**2 + l3**2*cos(phi3(t))**2)*Derivative(phi3(t), t)**2/2 + m3*(l1*l2*sin(phi1(t))*sin(phi2(t)) + l1*l2*cos(phi1(t))*cos(phi2(t)))*Derivative(phi1(t), t)*Derivative(phi2(t), t) + m3*(l1*l3*sin(phi1(t))*sin(phi3(t)) + l1*l3*cos(phi1(t))*cos(phi3(t)))*Derivative(phi1(t), t)*Derivative(phi3(t), t) + m3*(l2*l3*sin(phi2(t))*sin(phi3(t)) + l2*l3*cos(phi2(t))*cos(phi3(t)))*Derivative(phi2(t), t)*Derivative(phi3(t), t)

# %%
E_L = [smp.diff(L, q[u]) - smp.diff(smp.diff(L, q_d[u]), t).simplify() for u in range(n)]

print('Las ecuaciones de euler lagrange:')
E_L
# Out:
# Las ecuaciones de euler lagrange:
# ⎡                                                                   ⎛        2
# ⎢                                                                   ⎜       d
# ⎢-g⋅l₁⋅m₁⋅sin(φ₁(t)) - g⋅l₁⋅m₂⋅sin(φ₁(t)) - g⋅l₁⋅m₃⋅sin(φ₁(t)) - l₁⋅⎜l₁⋅m₁⋅───
# ⎢                                                                   ⎜        2
# ⎣                                                                   ⎝      dt
#
#                   2                  2
#                  d                  d                 ⎛d           d        ⎞
# (φ₁(t)) + l₁⋅m₂⋅───(φ₁(t)) + l₁⋅m₃⋅───(φ₁(t)) - l₂⋅m₂⋅⎜──(φ₁(t)) - ──(φ₂(t))⎟⋅
#                   2                  2                ⎝dt          dt       ⎠
#                 dt                 dt
#
#                                                           2
#                    d                                     d                 ⎛d
# sin(φ₁(t) - φ₂(t))⋅──(φ₂(t)) + l₂⋅m₂⋅cos(φ₁(t) - φ₂(t))⋅───(φ₂(t)) - l₂⋅m₃⋅⎜──
#                    dt                                     2                ⎝dt
#                                                         dt
#
#
#           d        ⎞                    d
# (φ₁(t)) - ──(φ₂(t))⎟⋅sin(φ₁(t) - φ₂(t))⋅──(φ₂(t)) + l₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅─
#           dt       ⎠                    dt
#                                                                              d
#
#  2
# d                 ⎛d           d        ⎞                    d
# ──(φ₂(t)) - l₃⋅m₃⋅⎜──(φ₁(t)) - ──(φ₃(t))⎟⋅sin(φ₁(t) - φ₃(t))⋅──(φ₃(t)) + l₃⋅m₃
#  2                ⎝dt          dt       ⎠                    dt
# t
#
#                       2       ⎞
#                      d        ⎟
# ⋅cos(φ₁(t) - φ₃(t))⋅───(φ₃(t))⎟ + m₂⋅(-l₁⋅l₂⋅sin(φ₁(t))⋅cos(φ₂(t)) + l₁⋅l₂⋅sin
#                       2       ⎟
#                     dt        ⎠
#
#
#                     d         d
# (φ₂(t))⋅cos(φ₁(t)))⋅──(φ₁(t))⋅──(φ₂(t)) + m₃⋅(-l₁⋅l₂⋅sin(φ₁(t))⋅cos(φ₂(t)) + l
#                     dt        dt
#
#
#
#                             d         d
# ₁⋅l₂⋅sin(φ₂(t))⋅cos(φ₁(t)))⋅──(φ₁(t))⋅──(φ₂(t)) + m₃⋅(-l₁⋅l₃⋅sin(φ₁(t))⋅cos(φ₃
#                             dt        dt
#
#
#
#                                     d         d
# (t)) + l₁⋅l₃⋅sin(φ₃(t))⋅cos(φ₁(t)))⋅──(φ₁(t))⋅──(φ₃(t)), -g⋅l₂⋅m₂⋅sin(φ₂(t)) -
#                                     dt        dt
#
#
#                          ⎛
#                          ⎜        ⎛d           d        ⎞                    d
#  g⋅l₂⋅m₃⋅sin(φ₂(t)) - l₂⋅⎜- l₁⋅m₂⋅⎜──(φ₁(t)) - ──(φ₂(t))⎟⋅sin(φ₁(t) - φ₂(t))⋅─
#                          ⎜        ⎝dt          dt       ⎠                    d
#                          ⎝
#
#                                       2
#                                      d                 ⎛d           d        ⎞
# ─(φ₁(t)) + l₁⋅m₂⋅cos(φ₁(t) - φ₂(t))⋅───(φ₁(t)) - l₁⋅m₃⋅⎜──(φ₁(t)) - ──(φ₂(t))⎟
# t                                     2                ⎝dt          dt       ⎠
#                                     dt
#
#                                                            2
#                     d                                     d                  d
# ⋅sin(φ₁(t) - φ₂(t))⋅──(φ₁(t)) + l₁⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅───(φ₁(t)) + l₂⋅m₂⋅──
#                     dt                                     2
#                                                          dt                 dt
#
# 2                  2
#                   d                 ⎛d           d        ⎞
# ─(φ₂(t)) + l₂⋅m₃⋅───(φ₂(t)) - l₃⋅m₃⋅⎜──(φ₂(t)) - ──(φ₃(t))⎟⋅sin(φ₂(t) - φ₃(t))
# 2                  2                ⎝dt          dt       ⎠
#                  dt
#
#                                         2       ⎞
#  d                                     d        ⎟
# ⋅──(φ₃(t)) + l₃⋅m₃⋅cos(φ₂(t) - φ₃(t))⋅───(φ₃(t))⎟ + m₂⋅(l₁⋅l₂⋅sin(φ₁(t))⋅cos(φ
#  dt                                     2       ⎟
#                                       dt        ⎠
#
#
#                                      d         d
# ₂(t)) - l₁⋅l₂⋅sin(φ₂(t))⋅cos(φ₁(t)))⋅──(φ₁(t))⋅──(φ₂(t)) + m₃⋅(l₁⋅l₂⋅sin(φ₁(t)
#                                      dt        dt
#
#
#
#                                             d         d
# )⋅cos(φ₂(t)) - l₁⋅l₂⋅sin(φ₂(t))⋅cos(φ₁(t)))⋅──(φ₁(t))⋅──(φ₂(t)) + m₃⋅(-l₂⋅l₃⋅s
#                                             dt        dt
#
#
#
#                                                     d         d
# in(φ₂(t))⋅cos(φ₃(t)) + l₂⋅l₃⋅sin(φ₃(t))⋅cos(φ₂(t)))⋅──(φ₂(t))⋅──(φ₃(t)), -g⋅l₃
#                                                     dt        dt
#
#
#                        ⎛
#                        ⎜     ⎛d           d        ⎞                    d
# ⋅m₃⋅sin(φ₃(t)) - l₃⋅m₃⋅⎜- l₁⋅⎜──(φ₁(t)) - ──(φ₃(t))⎟⋅sin(φ₁(t) - φ₃(t))⋅──(φ₁(
#                        ⎜     ⎝dt          dt       ⎠                    dt
#                        ⎝
#
#                               2
#                              d              ⎛d           d        ⎞
# t)) + l₁⋅cos(φ₁(t) - φ₃(t))⋅───(φ₁(t)) - l₂⋅⎜──(φ₂(t)) - ──(φ₃(t))⎟⋅sin(φ₂(t)
#                               2             ⎝dt          dt       ⎠
#                             dt
#
#                                              2               2       ⎞
#          d                                  d               d        ⎟
# - φ₃(t))⋅──(φ₂(t)) + l₂⋅cos(φ₂(t) - φ₃(t))⋅───(φ₂(t)) + l₃⋅───(φ₃(t))⎟ + m₃⋅(l
#          dt                                  2               2       ⎟
#                                            dt              dt        ⎠
#
#
#                                                           d         d
# ₁⋅l₃⋅sin(φ₁(t))⋅cos(φ₃(t)) - l₁⋅l₃⋅sin(φ₃(t))⋅cos(φ₁(t)))⋅──(φ₁(t))⋅──(φ₃(t))
#                                                           dt        dt
#
#
#
#                                                                  d         d
# + m₃⋅(l₂⋅l₃⋅sin(φ₂(t))⋅cos(φ₃(t)) - l₂⋅l₃⋅sin(φ₃(t))⋅cos(φ₂(t)))⋅──(φ₂(t))⋅──(
#                                                                  dt        dt
#
#
#       ⎤
#       ⎥
# φ₃(t))⎥
#       ⎥
#       ⎦

# %%
print(E_L)
# Out:
# [-g*l1*m1*sin(phi1(t)) - g*l1*m2*sin(phi1(t)) - g*l1*m3*sin(phi1(t)) - l1*(l1*m1*Derivative(phi1(t), (t, 2)) + l1*m2*Derivative(phi1(t), (t, 2)) + l1*m3*Derivative(phi1(t), (t, 2)) - l2*m2*(Derivative(phi1(t), t) - Derivative(phi2(t), t))*sin(phi1(t) - phi2(t))*Derivative(phi2(t), t) + l2*m2*cos(phi1(t) - phi2(t))*Derivative(phi2(t), (t, 2)) - l2*m3*(Derivative(phi1(t), t) - Derivative(phi2(t), t))*sin(phi1(t) - phi2(t))*Derivative(phi2(t), t) + l2*m3*cos(phi1(t) - phi2(t))*Derivative(phi2(t), (t, 2)) - l3*m3*(Derivative(phi1(t), t) - Derivative(phi3(t), t))*sin(phi1(t) - phi3(t))*Derivative(phi3(t), t) + l3*m3*cos(phi1(t) - phi3(t))*Derivative(phi3(t), (t, 2))) + m2*(-l1*l2*sin(phi1(t))*cos(phi2(t)) + l1*l2*sin(phi2(t))*cos(phi1(t)))*Derivative(phi1(t), t)*Derivative(phi2(t), t) + m3*(-l1*l2*sin(phi1(t))*cos(phi2(t)) + l1*l2*sin(phi2(t))*cos(phi1(t)))*Derivative(phi1(t), t)*Derivative(phi2(t), t) + m3*(-l1*l3*sin(phi1(t))*cos(phi3(t)) + l1*l3*sin(phi3(t))*cos(phi1(t)))*Derivative(phi1(t), t)*Derivative(phi3(t), t), -g*l2*m2*sin(phi2(t)) - g*l2*m3*sin(phi2(t)) - l2*(-l1*m2*(Derivative(phi1(t), t) - Derivative(phi2(t), t))*sin(phi1(t) - phi2(t))*Derivative(phi1(t), t) + l1*m2*cos(phi1(t) - phi2(t))*Derivative(phi1(t), (t, 2)) - l1*m3*(Derivative(phi1(t), t) - Derivative(phi2(t), t))*sin(phi1(t) - phi2(t))*Derivative(phi1(t), t) + l1*m3*cos(phi1(t) - phi2(t))*Derivative(phi1(t), (t, 2)) + l2*m2*Derivative(phi2(t), (t, 2)) + l2*m3*Derivative(phi2(t), (t, 2)) - l3*m3*(Derivative(phi2(t), t) - Derivative(phi3(t), t))*sin(phi2(t) - phi3(t))*Derivative(phi3(t), t) + l3*m3*cos(phi2(t) - phi3(t))*Derivative(phi3(t), (t, 2))) + m2*(l1*l2*sin(phi1(t))*cos(phi2(t)) - l1*l2*sin(phi2(t))*cos(phi1(t)))*Derivative(phi1(t), t)*Derivative(phi2(t), t) + m3*(l1*l2*sin(phi1(t))*cos(phi2(t)) - l1*l2*sin(phi2(t))*cos(phi1(t)))*Derivative(phi1(t), t)*Derivative(phi2(t), t) + m3*(-l2*l3*sin(phi2(t))*cos(phi3(t)) + l2*l3*sin(phi3(t))*cos(phi2(t)))*Derivative(phi2(t), t)*Derivative(phi3(t), t), -g*l3*m3*sin(phi3(t)) - l3*m3*(-l1*(Derivative(phi1(t), t) - Derivative(phi3(t), t))*sin(phi1(t) - phi3(t))*Derivative(phi1(t), t) + l1*cos(phi1(t) - phi3(t))*Derivative(phi1(t), (t, 2)) - l2*(Derivative(phi2(t), t) - Derivative(phi3(t), t))*sin(phi2(t) - phi3(t))*Derivative(phi2(t), t) + l2*cos(phi2(t) - phi3(t))*Derivative(phi2(t), (t, 2)) + l3*Derivative(phi3(t), (t, 2))) + m3*(l1*l3*sin(phi1(t))*cos(phi3(t)) - l1*l3*sin(phi3(t))*cos(phi1(t)))*Derivative(phi1(t), t)*Derivative(phi3(t), t) + m3*(l2*l3*sin(phi2(t))*cos(phi3(t)) - l2*l3*sin(phi3(t))*cos(phi2(t)))*Derivative(phi2(t), t)*Derivative(phi3(t), t)]

# %%
sols = smp.linsolve(E_L, tuple(q_dd))
sols
# Out:
# ⎧⎛
# ⎪⎜
# ⎪⎜
# ⎨⎜
# ⎪⎜- ──────────────────────────────────────────────────────────────────────────
# ⎪⎜                         2                                  2    2
# ⎩⎝  l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#              2                 2
# ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t)
#
#
#
#
#                                                       g⋅m₁⋅m₂⋅sin(φ₁(t))
# ──────────────────────────────────────────────────────────────────────────────
#                                                       2
# )⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#        2                                    2    2                         2
# ⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                2    2
# os(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) -
#
#
#
#
#
# ──────────────────────────────────────────── + ───────────────────────────────
#               2    2                       2                          2
# φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                            2    2                       2                 2
# - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# (t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃
#
#
#
#                                2
#          g⋅m₁⋅m₃⋅sin(φ₁(t))⋅cos (φ₂(t) - φ₃(t))
# ──────────────────────────────────────────────────────────────────────────────
#                    2                              2
# (t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#          2    2                         2
# ₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                             2    2                       2    2
# )⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t))
#
#
#
#
#
# ───────── - ──────────────────────────────────────────────────────────────────
#         2                          2                                  2    2
#  + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                      2                 2
# ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t)
#
#
#
#
#                                                               g⋅m₁⋅m₃⋅sin(φ₁(t
# ──────────────────────────────────────────────────────────────────────────────
#                                                               2
#  - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t))
#
#
#
#
# ))
# ──────────────────────────────────────────────────────────────────────────────
#                2                                    2    2
#  - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      2                                                                 2    2
# l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (
#
#
#
#
#
# ──────────────────────────────────────────────────── - ───────────────────────
#                       2    2                       2
# φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# 2                                  2    2                       2
#  (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#     2
# ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂
#
#
#
#
#                            g⋅m₂⋅m₂⋅sin(φ₁(t))
# ──────────────────────────────────────────────────────────────────────────────
#                            2                              2
# (t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                  2    2                         2
# ⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                     2    2                       2    2
#  - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t)
#
#
#
#
#
# ───────────────── + ──────────────────────────────────────────────────────────
#                 2                          2
# - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# 2    2                       2                 2
#  ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅c
#
#
#
#
#                                                             g⋅m₂⋅m₂⋅sin(φ₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#                                                                       2
# os(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t)
#
#
#
#
# ⋅cos(φ₁(t) - φ₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#                        2                                    2    2
# - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#              2
# t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m
#
#
#
#
#
# ──────────────────────────────────────────────────────────── - ───────────────
#  2    2                       2    2                       2
# ₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         2                                  2    2                       2
# ₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#             2
# l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t)
#
#
#
#
#                                    g⋅m₂⋅m₃⋅sin(φ₁(t))
# ──────────────────────────────────────────────────────────────────────────────
#                                    2                              2
# )⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                          2    2                         2
# (t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                             2    2                       2
# os(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos
#
#
#
#
#
# ───────────────────────── + ──────────────────────────────────────────────────
# 2                       2                          2
#  (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#         2    2                       2                 2
#  - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁
#
#
#
#
#                                                                     g⋅m₂⋅m₃⋅si
# ──────────────────────────────────────────────────────────────────────────────
#
# ⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos
#
#
#
#
# n(φ₂(t))⋅cos(φ₁(t) - φ₂(t))
# ──────────────────────────────────────────────────────────────────────────────
# 2                              2                                    2    2
#  (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                      2
# t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────── - ───────
#          2    2                       2    2                       2
# ) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                 2                                  2    2
# ₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#   2                 2
# m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t)
#
#
#
#
#                         g⋅m₂⋅m₃⋅sin(φ₃(t))⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₂(t) - φ₃(t
# ──────────────────────────────────────────────────────────────────────────────
#                                            2                              2
#  - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂
#
#
#
#
# ))
# ──────────────────────────────────────────────────────────────────────────────
#                                  2    2                         2
# (t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                     2    2
# φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁
#
#
#
#
#
# ───────────────────────────────── + ──────────────────────────────────────────
#    2    2                       2                          2
# ⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) +
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                 2    2                       2                 2
# l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)
#
#
#
#
#                                                                             g⋅
# ──────────────────────────────────────────────────────────────────────────────
#
# ) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m
#
#
#
#
# m₂⋅m₃⋅sin(φ₃(t))⋅cos(φ₁(t) - φ₃(t))
# ──────────────────────────────────────────────────────────────────────────────
#         2                              2                                    2
# ₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#    2                         2
# cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────── +
#                  2    2                       2    2                       2
#  - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃
#
#
#
#
#
#  ─────────────────────────────────────────────────────────────────────────────
#                         2                                  2    2
#  l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#           2                 2
# )) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅c
#
#
#
#                                                                2
#                                          g⋅m₂⋅m₃⋅sin(φ₁(t))⋅cos (φ₂(t) - φ₃(t)
# ──────────────────────────────────────────────────────────────────────────────
#                                                    2
# os(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃
#
#
#
#
# )
# ──────────────────────────────────────────────────────────────────────────────
#     2                                    2    2                         2
# ⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                             2    2
# φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(
#
#
#
#
#
# ───────────────────────────────────────── - ──────────────────────────────────
#            2    2                       2                          2
# t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                         2    2                       2                 2
# ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#  - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)
#
#
#
#
#                 g⋅m₂⋅m₃⋅sin(φ₁(t))
# ──────────────────────────────────────────────────────────────────────────────
#                 2                              2
# ) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#       2    2                         2
#  l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                          2    2                       2    2
# os(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) +
#
#
#
#
#
# ────── + ─────────────────────────────────────────────────────────────────────
#      2                          2                                  2    2
# l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                   2                 2
# ) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) -
#
#
#
#
#                                                  g⋅m₂⋅m₃⋅sin(φ₂(t))⋅cos(φ₁(t)
# ──────────────────────────────────────────────────────────────────────────────
#                                                            2
# φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) -
#
#
#
#
# - φ₂(t))
# ──────────────────────────────────────────────────────────────────────────────
#             2                                    2    2
# l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#   2                                                                 2    2
# m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(
#
#
#
#
#
# ───────────────────────────────────────────────── - ──────────────────────────
#                    2    2                       2                          2
# t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                 2    2                       2
# ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅co
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#  2
# s (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t)
#
#
#
#
#      g⋅m₂⋅m₃⋅sin(φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t))
# ──────────────────────────────────────────────────────────────────────────────
#                         2                              2
#  - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#               2    2                         2
# ⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                  2    2                       2    2
# φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ
#
#
#
#
#
# ────────────── + ─────────────────────────────────────────────────────────────
#              2                          2                                  2
# ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅c
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#   2                       2                 2
# os (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(
#
#
#
#
#                                                          g⋅m₃⋅m₃⋅sin(φ₁(t))⋅co
# ──────────────────────────────────────────────────────────────────────────────
#                                                                    2
# φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ
#
#
#
#  2
# s (φ₂(t) - φ₃(t))
# ──────────────────────────────────────────────────────────────────────────────
#                     2                                    2    2
# ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t))
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#           2                                                                 2
#  + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅
#
#
#
#
#
# ───────────────────────────────────────────────────────── - ──────────────────
#    2                       2    2                       2
# cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      2                                  2    2                       2
# ₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ - l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#          2
# m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅c
#
#
#
#
#                                 g⋅m₃⋅m₃⋅sin(φ₁(t))
# ──────────────────────────────────────────────────────────────────────────────
#                                 2                              2
# os(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ₂(t) - φ₃(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                       2    2                         2
# ) + 2⋅l₁⋅m₂⋅m₃ - l₁⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                          2    2                       2    2
# φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₁⋅m₃ ⋅cos (φ
#
#
#
#
#
# ────────────────────── + ─────────────────────────────────────────────────────
#                      2                          2
# ₂(t) - φ₃(t)) + l₁⋅m₃    l₁⋅m₁⋅m₂ - l₁⋅m₁⋅m₃⋅cos (φ₂(t) - φ₃(t)) + l₁⋅m₁⋅m₃ -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      2    2                       2                 2
# l₁⋅m₂ ⋅cos (φ₁(t) - φ₂(t)) + l₁⋅m₂  - 2⋅l₁⋅m₂⋅m₃⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₁⋅m₂
#
#
#
#
#                                                                  g⋅m₃⋅m₃⋅sin(φ
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            2
# ⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₁⋅m₂⋅m₃⋅cos (φ
#
#
#
#
# ₂(t))⋅cos(φ₁(t) - φ₂(t))
# ...
#
# ───────────────────────────────── + ──────────────────────────────────────────
#    3    2                       3                         2    2
# ⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₃⋅m₃    l₃⋅m₁⋅m₂⋅m₃ - l₃⋅m₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#             2        2       2                       2                2    2
# ) + l₃⋅m₁⋅m₃  - l₃⋅m₂ ⋅m₃⋅cos (φ₁(t) - φ₂(t)) + l₃⋅m₂ ⋅m₃ - 2⋅l₃⋅m₂⋅m₃ ⋅cos (φ
#
#
#                                                                           3
#                                                                      l₃⋅m₃ ⋅si
#
# ──────────────────────────────────────────────────────────────────────────────
#                           2
# ₁(t) - φ₂(t)) + 2⋅l₃⋅m₂⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) -
#
#
#                                        d         d
# n(φ₂(t))⋅cos(φ₂(t) - φ₃(t))⋅cos(φ₃(t))⋅──(φ₂(t))⋅──(φ₃(t))
#                                        dt        dt
# ──────────────────────────────────────────────────────────────────────────────
#                  2    2                          2    2
# φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₃⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#      2        3    2                         3
# m₂⋅m₃  - l₃⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₃⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                  3    2                       3    2
# φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₃⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₃⋅m₃ ⋅cos (φ₂(t) - φ
#
#
#
#
#
# ────────────── + ─────────────────────────────────────────────────────────────
#              3                         2    2                          2
# ₃(t)) + l₃⋅m₃    l₃⋅m₁⋅m₂⋅m₃ - l₃⋅m₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₃⋅m₁⋅m₃  - l₃⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#   2       2                       2                2    2
# m₂ ⋅m₃⋅cos (φ₁(t) - φ₂(t)) + l₃⋅m₂ ⋅m₃ - 2⋅l₃⋅m₂⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l
#
#
#                                               3
#                                          l₃⋅m₃ ⋅sin(φ₃(t))⋅cos(φ₁(t) - φ₂(t))⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#        2                                                                    2
# ₃⋅m₂⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅
#
#
#                               d         d
# cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t))⋅──(φ₂(t))⋅──(φ₃(t))
#                               dt        dt
# ──────────────────────────────────────────────────────────────────────────────
#    2                          2    2                            2        3
# cos (φ₁(t) - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₃⋅m₂⋅m₃  - l₃⋅m₃ ⋅cos
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# 2                         3
#  (φ₁(t) - φ₂(t)) + 2⋅l₃⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) -
#
#
#
#
#
# ───────────────────────────────────────────────────────────────────────── + ──
#               3    2                       3    2                       3
# φ₃(t)) - l₃⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₃⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₃⋅m₃    l₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                     2    2                          2        2       2
# ⋅m₁⋅m₂⋅m₃ - l₃⋅m₁⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₃⋅m₁⋅m₃  - l₃⋅m₂ ⋅m₃⋅cos (φ₁(t) -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                2                2    2                            2
#  φ₂(t)) + l₃⋅m₂ ⋅m₃ - 2⋅l₃⋅m₂⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₃⋅m₂⋅m₃ ⋅cos(φ₁(t)
#
#
#                            3
#                       l₃⋅m₃ ⋅sin(φ₃(t))⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₂(t) - φ₃(t))⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                          2    2
# - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ₁(t) - φ₃(t))
#
#
#            d         d
# cos(φ₁(t))⋅──(φ₁(t))⋅──(φ₃(t))
#            dt        dt
# ──────────────────────────────────────────────────────────────────────────────
#            2    2                            2        3    2
#  - l₃⋅m₂⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + 2⋅l₃⋅m₂⋅m₃  - l₃⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) +
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#        3                                                                 3
# 2⋅l₃⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₃⋅m₃ ⋅cos
#
#
#
#
#
# ────────────────────────────────────────────────────── - ─────────────────────
# 2                       3    2                       3
#  (φ₁(t) - φ₃(t)) - l₃⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₃⋅m₃    l₃⋅m₁⋅m₂⋅m₃ - l₃⋅m₁⋅m
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#  2    2                          2        2       2                       2
# ₃ ⋅cos (φ₂(t) - φ₃(t)) + l₃⋅m₁⋅m₃  - l₃⋅m₂ ⋅m₃⋅cos (φ₁(t) - φ₂(t)) + l₃⋅m₂ ⋅m₃
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#              2    2                            2
#  - 2⋅l₃⋅m₂⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₃⋅m₂⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t)
#
#
#                  3                                          d         d
#             l₃⋅m₃ ⋅sin(φ₃(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₁(t))⋅──(φ₁(t))⋅──(φ₃(t)
#                                                             dt        dt
# ──────────────────────────────────────────────────────────────────────────────
#                                       2    2                          2    2
# - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ
#
#
#
# )
#
# ──────────────────────────────────────────────────────────────────────────────
#                           2        3    2                         3
# ₂(t) - φ₃(t)) + 2⋅l₃⋅m₂⋅m₃  - l₃⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₃⋅m₃ ⋅cos(φ₁(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                       3    2
# - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₃⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) -
#
#
#
#
#
# ─────────────────────────────────── - ────────────────────────────────────────
#      3    2                       3                         2    2
# l₃⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + l₃⋅m₃    l₃⋅m₁⋅m₂⋅m₃ - l₃⋅m₁⋅m₃ ⋅cos (φ₂(t) - φ₃(
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#               2        2       2                       2                2    2
# t)) + l₃⋅m₁⋅m₃  - l₃⋅m₂ ⋅m₃⋅cos (φ₁(t) - φ₂(t)) + l₃⋅m₂ ⋅m₃ - 2⋅l₃⋅m₂⋅m₃ ⋅cos
#
#
#                                                                             3
#                                                                        l₃⋅m₃ ⋅
#
# ──────────────────────────────────────────────────────────────────────────────
#                             2
# (φ₁(t) - φ₂(t)) + 2⋅l₃⋅m₂⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t) - φ₃(t))⋅cos(φ₂(t)
#
#
#                                          d         d
# sin(φ₃(t))⋅cos(φ₂(t) - φ₃(t))⋅cos(φ₂(t))⋅──(φ₂(t))⋅──(φ₃(t))
#                                          dt        dt
# ──────────────────────────────────────────────────────────────────────────────
#                    2    2                          2    2
# - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₃⋅m₂⋅m₃ ⋅cos (φ₂(t) - φ₃(t)) + 2⋅l
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#        2        3    2                         3
# ₃⋅m₂⋅m₃  - l₃⋅m₃ ⋅cos (φ₁(t) - φ₂(t)) + 2⋅l₃⋅m₃ ⋅cos(φ₁(t) - φ₂(t))⋅cos(φ₁(t)
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                    3    2                       3    2
# - φ₃(t))⋅cos(φ₂(t) - φ₃(t)) - l₃⋅m₃ ⋅cos (φ₁(t) - φ₃(t)) - l₃⋅m₃ ⋅cos (φ₂(t) -
#
#                 ⎞⎫
#                 ⎟⎪
#                 ⎟⎪
#                 ⎟⎬
# ────────────────⎟⎪
#                3⎟⎪
#  φ₃(t)) + l₃⋅m₃ ⎠⎭

# %%
print(smp.latex(sols))
# Out:
# \left\{\left( - \frac{g m_{1} m_{2} \sin{\left(\phi_{1}{\left(t \right)} \right)}}{l_{1} m_{1} m_{2} - l_{1} m_{1} m_{3} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + l_{1} m_{1} m_{3} - l_{1} m_{2}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + l_{1} m_{2}^{2} - 2 l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + 2 l_{1} m_{2} m_{3} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} \cos{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + 2 l_{1} m_{2} m_{3} - l_{1} m_{3}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + 2 l_{1} m_{3}^{2} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} \cos{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{3}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{3}^{2} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + l_{1} m_{3}^{2}} + \frac{g m_{1} m_{3} \sin{\left(\phi_{1}{\left(t \right)} \right)} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)}}{l_{1} m_{1} m_{2} - l_{1} m_{1} m_{3} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + l_{1} m_{1} m_{3} - l_{1} m_{2}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + l_{1} m_{2}^{2} - 2 l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + 2 l_{1} m_{2} m_{3} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} \cos{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + 2 l_{1} m_{2} m_{3} - l_{1} m_{3}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + 2 l_{1} m_{3}^{2} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} \cos{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{3}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{3}^{2} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + l_{1} m_{3}^{2}} - \frac{g m_{1} m_{3} \sin{\left(\phi_{1}{\left(t \right)} \right)}}{l_{1} m_{1} m_{2} - l_{1} m_{1} m_{3} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + l_{1} m_{1} m_{3} - l_{1} m_{2}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + l_{1} m_{2}^{2} - 2 l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + 2 l_{1} m_{2} m_{3} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} \cos{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} - l_{1} m_{2} m_{3} \cos^{2}{\left(\phi_{2}{\left(t \right)} - \phi_{3}{\left(t \right)} \right)} + 2 l_{1} m_{2} m_{3} - l_{1} m_{3}^{2} \cos^{2}{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\left(t \right)} \right)} + 2 l_{1} m_{3}^{2} \cos{\left(\phi_{1}{\left(t \right)} - \phi_{2}{\le ...

# %%
sols = {}
for acceleration, equation in zip(q_dd, E_L):
    c = smp.diff(equation, acceleration)
    solution = (acceleration - equation/c).simplify()
    sols[acceleration] = solution

sols
# Out:
# ⎧             ⎛
# ⎪             ⎜
# ⎪            -⎜g⋅m₁⋅sin(φ₁(t)) + g⋅m₂⋅sin(φ₁(t)) + g⋅m₃⋅sin(φ₁(t)) + l₂⋅m₂⋅sin
# ⎪  2          ⎜
# ⎨ d           ⎝
# ⎪───(φ₁(t)): ─────────────────────────────────────────────────────────────────
# ⎪  2
# ⎪dt
# ⎩
#
#                            2                              2
#                 ⎛d        ⎞                              d
# (φ₁(t) - φ₂(t))⋅⎜──(φ₂(t))⎟  + l₂⋅m₂⋅cos(φ₁(t) - φ₂(t))⋅───(φ₂(t)) + l₂⋅m₃⋅sin
#                 ⎝dt       ⎠                               2
#                                                         dt
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        l₁⋅(m₁
#
#
#
#                            2                              2
#                 ⎛d        ⎞                              d
# (φ₁(t) - φ₂(t))⋅⎜──(φ₂(t))⎟  + l₂⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅───(φ₂(t)) + l₃⋅m₃⋅sin
#                 ⎝dt       ⎠                               2
#                                                         dt
# ──────────────────────────────────────────────────────────────────────────────
# + m₂ + m₃)
#
#
#
#                            2                              2       ⎞
#                 ⎛d        ⎞                              d        ⎟
# (φ₁(t) - φ₃(t))⋅⎜──(φ₃(t))⎟  + l₃⋅m₃⋅cos(φ₁(t) - φ₃(t))⋅───(φ₃(t))⎟
#                 ⎝dt       ⎠                               2       ⎟     2
#                                                         dt        ⎠    d
# ────────────────────────────────────────────────────────────────────, ───(φ₂(t
#                                                                         2
#                                                                       dt
#
#
#                                                                              2
#                                                                   ⎛d        ⎞
#     -g⋅m₂⋅sin(φ₂(t)) - g⋅m₃⋅sin(φ₂(t)) + l₁⋅m₂⋅sin(φ₁(t) - φ₂(t))⋅⎜──(φ₁(t))⎟
#                                                                   ⎝dt       ⎠
#
# )): ──────────────────────────────────────────────────────────────────────────
#
#
#
#
#                               2                                              2
#                              d                                    ⎛d        ⎞
#  - l₁⋅m₂⋅cos(φ₁(t) - φ₂(t))⋅───(φ₁(t)) + l₁⋅m₃⋅sin(φ₁(t) - φ₂(t))⋅⎜──(φ₁(t))⎟
#                               2                                   ⎝dt       ⎠
#                             dt
# ──────────────────────────────────────────────────────────────────────────────
#                                                       l₂⋅(m₂ + m₃)
#
#
#
#                               2                                              2
#                              d                                    ⎛d        ⎞
#  - l₁⋅m₃⋅cos(φ₁(t) - φ₂(t))⋅───(φ₁(t)) - l₃⋅m₃⋅sin(φ₂(t) - φ₃(t))⋅⎜──(φ₃(t))⎟
#                               2                                   ⎝dt       ⎠
#                             dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                               2
#                              d
#  - l₃⋅m₃⋅cos(φ₂(t) - φ₃(t))⋅───(φ₃(t))              -g⋅m₃⋅sin(φ₃(t)) + l₁⋅m₃⋅s
#                               2           2
#                             dt           d
# ──────────────────────────────────────, ───(φ₃(t)): ──────────────────────────
#                                           2
#                                         dt
#
#
#                              2                              2
#                   ⎛d        ⎞                              d
# in(φ₁(t) - φ₃(t))⋅⎜──(φ₁(t))⎟  - l₁⋅m₃⋅cos(φ₁(t) - φ₃(t))⋅───(φ₁(t)) + l₂⋅m₃⋅s
#                   ⎝dt       ⎠                               2
#                                                           dt
# ──────────────────────────────────────────────────────────────────────────────
#                                                          l₃⋅m₃
#
#
#
#                              2                              2       ⎫
#                   ⎛d        ⎞                              d        ⎪
# in(φ₂(t) - φ₃(t))⋅⎜──(φ₂(t))⎟  - l₂⋅m₃⋅cos(φ₂(t) - φ₃(t))⋅───(φ₂(t))⎪
#                   ⎝dt       ⎠                               2       ⎪
#                                                           dt        ⎬
# ────────────────────────────────────────────────────────────────────⎪
#                                                                     ⎪
#                                                                     ⎪
#                                                                     ⎭

# %%
print(sols)
# Out:
# {(-g*m1*m2*sin(phi1(t))/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m2**2*cos(phi1(t) - phi2(t))**2 + l1*m2**2 - 2*l1*m2*m3*cos(phi1(t) - phi2(t))**2 + 2*l1*m2*m3*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m2*m3*cos(phi1(t) - phi3(t))**2 - l1*m2*m3*cos(phi2(t) - phi3(t))**2 + 2*l1*m2*m3 - l1*m3**2*cos(phi1(t) - phi2(t))**2 + 2*l1*m3**2*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m3**2*cos(phi1(t) - phi3(t))**2 - l1*m3**2*cos(phi2(t) - phi3(t))**2 + l1*m3**2) + g*m1*m3*sin(phi1(t))*cos(phi2(t) - phi3(t))**2/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m2**2*cos(phi1(t) - phi2(t))**2 + l1*m2**2 - 2*l1*m2*m3*cos(phi1(t) - phi2(t))**2 + 2*l1*m2*m3*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m2*m3*cos(phi1(t) - phi3(t))**2 - l1*m2*m3*cos(phi2(t) - phi3(t))**2 + 2*l1*m2*m3 - l1*m3**2*cos(phi1(t) - phi2(t))**2 + 2*l1*m3**2*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m3**2*cos(phi1(t) - phi3(t))**2 - l1*m3**2*cos(phi2(t) - phi3(t))**2 + l1*m3**2) - g*m1*m3*sin(phi1(t))/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m2**2*cos(phi1(t) - phi2(t))**2 + l1*m2**2 - 2*l1*m2*m3*cos(phi1(t) - phi2(t))**2 + 2*l1*m2*m3*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m2*m3*cos(phi1(t) - phi3(t))**2 - l1*m2*m3*cos(phi2(t) - phi3(t))**2 + 2*l1*m2*m3 - l1*m3**2*cos(phi1(t) - phi2(t))**2 + 2*l1*m3**2*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m3**2*cos(phi1(t) - phi3(t))**2 - l1*m3**2*cos(phi2(t) - phi3(t))**2 + l1*m3**2) - g*m2*m2*sin(phi1(t))/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m2**2*cos(phi1(t) - phi2(t))**2 + l1*m2**2 - 2*l1*m2*m3*cos(phi1(t) - phi2(t))**2 + 2*l1*m2*m3*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m2*m3*cos(phi1(t) - phi3(t))**2 - l1*m2*m3*cos(phi2(t) - phi3(t))**2 + 2*l1*m2*m3 - l1*m3**2*cos(phi1(t) - phi2(t))**2 + 2*l1*m3**2*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m3**2*cos(phi1(t) - phi3(t))**2 - l1*m3**2*cos(phi2(t) - phi3(t))**2 + l1*m3**2) + g*m2*m2*sin(phi2(t))*cos(phi1(t) - phi2(t))/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m2**2*cos(phi1(t) - phi2(t))**2 + l1*m2**2 - 2*l1*m2*m3*cos(phi1(t) - phi2(t))**2 + 2*l1*m2*m3*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m2*m3*cos(phi1(t) - phi3(t))**2 - l1*m2*m3*cos(phi2(t) - phi3(t))**2 + 2*l1*m2*m3 - l1*m3**2*cos(phi1(t) - phi2(t))**2 + 2*l1*m3**2*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m3**2*cos(phi1(t) - phi3(t))**2 - l1*m3**2*cos(phi2(t) - phi3(t))**2 + l1*m3**2) - g*m2*m3*sin(phi1(t))/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m2**2*cos(phi1(t) - phi2(t))**2 + l1*m2**2 - 2*l1*m2*m3*cos(phi1(t) - phi2(t))**2 + 2*l1*m2*m3*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m2*m3*cos(phi1(t) - phi3(t))**2 - l1*m2*m3*cos(phi2(t) - phi3(t))**2 + 2*l1*m2*m3 - l1*m3**2*cos(phi1(t) - phi2(t))**2 + 2*l1*m3**2*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m3**2*cos(phi1(t) - phi3(t))**2 - l1*m3**2*cos(phi2(t) - phi3(t))**2 + l1*m3**2) + g*m2*m3*sin(phi2(t))*cos(phi1(t) - phi2(t))/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m2**2*cos(phi1(t) - phi2(t))**2 + l1*m2**2 - 2*l1*m2*m3*cos(phi1(t) - phi2(t))**2 + 2*l1*m2*m3*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m2*m3*cos(phi1(t) - phi3(t))**2 - l1*m2*m3*cos(phi2(t) - phi3(t))**2 + 2*l1*m2*m3 - l1*m3**2*cos(phi1(t) - phi2(t))**2 + 2*l1*m3**2*cos(phi1(t) - phi2(t))*cos(phi1(t) - phi3(t))*cos(phi2(t) - phi3(t)) - l1*m3**2*cos(phi1(t) - phi3(t))**2 - l1*m3**2*cos(phi2(t) - phi3(t))**2 + l1*m3**2) - g*m2*m3*sin(phi3(t))*cos(phi1(t) - phi2(t))*cos(phi2(t) - phi3(t))/(l1*m1*m2 - l1*m1*m3*cos(phi2(t) - phi3(t))**2 + l1*m1*m3 - l1*m ...

# %%
dvdt_f = [smp.lambdify((t,p,m,q,q_d), sols[q_dd[u]]) for u in range(n)]
drdt_f = [smp.lambdify((t,p,m,q,q_d), q_d[u]) for u in range(n)]

dSdt_f = drdt_f + dvdt_f
def dSdt(S, t, p, m):
    return [dSdt_f[u](t,p,m,S[:n],S[n:]) for u in range(2*n)]

# %%
ans = odeint(dSdt, y0=initial_conditions, t=t_values, args=(p_values,m_values))
q_f = ans.T[:n]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 ans = odeint(dSdt, y0=initial_conditions, t=t_values, args=(p_values,m_values))
#       2 q_f = ans.T[:n]
#
# File c:\users\julia\appdata\local\programs\python\python38\lib\site-packages\scipy\integrate\odepack.py:241, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     239 t = copy(t)
#     240 y0 = copy(y0)
# --> 241 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     242                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     243                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     244                          int(bool(tfirst)))
#     245 if output[-1] < 0:
#     246     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# Input In [40], in dSdt(S, t, p, m)
#       5 def dSdt(S, t, p, m):
# ----> 6     return [dSdt_f[u](t,p,m,S[:n],S[n:]) for u in range(2*n)]
#
# Input In [40], in <listcomp>(.0)
#       5 def dSdt(S, t, p, m):
# ----> 6     return [dSdt_f[u](t,p,m,S[:n],S[n:]) for u in range(2*n)]
#
# File <lambdifygenerated-7>:8, in _lambdifygenerated(t, _Dummy_229, _Dummy_230, _Dummy_231, _Dummy_232)
#       4     [_Dummy_228, _Dummy_227] = _Dummy_231
#       5     [_Dummy_226, _Dummy_225] = _Dummy_232
#       6     return (  # Not supported in Python with SciPy and NumPy:
#       7   # Derivative
# ----> 8 -(-_Dummy_225**2*l*m2*sin(_Dummy_227 - _Dummy_228) + 2*g*m1*sin(_Dummy_228) + l*m2*cos(_Dummy_227 - _Dummy_228)*Derivative(_Dummy_227, (t, 2)))/(l*(m1 + m2)))
#
# NameError: name 'Derivative' is not defined

# %%
r_f = smp.lambdify((t,p,q), r)

x = []
y = []
pos = r_f(t_values,p_values,q_f)
for r_i in pos:
    x_i = r_i[0]
    y_i = r_i[1]
   
    x.append(x_i)
    y.append(y_i)

# %%
fig, ax = plt.subplots(dpi=1920/16)
line, = plt.plot([], [], "o", markersize=5)

scale = 5
ax.set_xlim(-scale, scale)
ax.set_ylim(-scale, scale)

textEquations = ''
diferentialNames = ''
for u in range(N):
    #diferentialName = r'$' + str(smp.latex(q_dd[u])) + '$ = ' + '\n'
    #diferentialNames += diferentialName
    textEquation = r'$' + str(smp.latex(sols[q_dd[u]])) + '$ '
    textEquation += '\n'
    textEquations += textEquation

plt.text(-scale, scale, diferentialNames)
#line.set_label(r'$' + str(smp.latex(sols[q_dd[0]])) + '$')
time_text = ax.text(-scale, scale-4, '', fontsize=15)
time_text.set_text(textEquations)
#plt.text(-5, 5, r'$' + str(smp.latex(q_dd[0])) + ' = ' + str(smp.latex(sols[q_dd[0]])) + '$',wrap=True)

def animate(frame):
    line.set_data(([0] + [y[i][0][frame] for i in range(N)], [0] + [-x[i][0][frame] for i in range(N)]))
    time_text.set_position((-scale - frame/4, scale-4))
    return line

anim = FuncAnimation(fig, animate, frames=frames_number, interval=20)
plt.axis('off')
plt.show()

# %%
FFwriter = animation.FFMpegWriter(fps=fps)
anim.save('GravityPendulum.mp4',writer=FFwriter)
